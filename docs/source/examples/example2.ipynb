# %% [markdown]
# # Example 2 Notebook

# %%
import aegiq_sdk as sdk

# %%
circuit = sdk.Circuit(4)

for i in range(20):
    circuit.add_bs(0)
    circuit.add_bs(2)
    circuit.add_bs(1)

circuit.display()
